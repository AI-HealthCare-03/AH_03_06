# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/AI-HealthCare-03/AH_03_06.git

# %% [markdown]
# ## 03 운동 강도 분류 (운동)
#
# 강도 구간 분류 모델 또는 규칙과 임상 조정 로직을 연계합니다.
