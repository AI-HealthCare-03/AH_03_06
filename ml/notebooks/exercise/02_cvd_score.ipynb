# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/AI-HealthCare-03/AH_03_06.git

# %% [markdown]
# ## 02 CVD 점수 (운동)
#
# 진료 수치 기반 CVD 위험 점수 산출과 구간 해석을 점검합니다.
