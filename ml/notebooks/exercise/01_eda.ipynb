# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/AI-HealthCare-03/AH_03_06.git

# %% [markdown]
# ## 01 EDA (운동)
#
# 운동 빈도·강도·심폐 지표 등 운동 관련 변수의 탐색적 분석을 수행합니다.
