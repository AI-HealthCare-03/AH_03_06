# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/AI-HealthCare-03/AH_03_06.git

# %% [markdown]
# ## 04 운동 가이드 (운동)
#
# 개인별 운동 가이드 문구·추천과 RAG/룰 기반 생성 파이프라인을 연결합니다.
