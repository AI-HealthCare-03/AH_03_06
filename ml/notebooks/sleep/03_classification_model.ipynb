# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/AI-HealthCare-03/AH_03_06.git

# %% [markdown]
# ## 03 분류 모델 (수면)
#
# 수면 상태 통합 분류 및 보조 모델 학습·평가를 수행합니다.
