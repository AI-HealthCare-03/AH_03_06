# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/AI-HealthCare-03/AH_03_06.git

# %% [markdown]
# ## 01 EDA (수면)
#
# 수면 시간, 설문, ESS 등 수면 관련 변수의 분포와 상관을 탐색합니다.
