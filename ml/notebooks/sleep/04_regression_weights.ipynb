# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/AI-HealthCare-03/AH_03_06.git

# %% [markdown]
# ## 04 회귀 가중치 (수면)
#
# 수면효율 예측 회귀식 계수 및 가이드 점수 산출을 검증합니다.
