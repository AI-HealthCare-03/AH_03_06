# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/AI-HealthCare-03/AH_03_06.git

# %% [markdown]
# ## 04 복약 가이드 (복약)
#
# 개인별 복약 안내 문구·경고와 RAG/룰 기반 출력 파이프라인을 연결합니다.
