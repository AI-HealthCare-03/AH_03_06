# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/AI-HealthCare-03/AH_03_06.git

# %% [markdown]
# ## 04 영양소 기준 (식단)
#
# 권장 섭취·상한 대비 영양소 정렬 및 기준표 연동 로직을 검증합니다.
